# %%
from keras.datasets import imdb
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from keras import Sequential
from keras.layers import Dense,Embedding,Flatten,LSTM

# %%
(X_train,y_train),(X_test,y_test) = imdb.load_data()

# %%
X_train.shape
# Out:
# (25000,)

# %%
X_train = pad_sequences(X_train,padding='post',maxlen=100)
X_test = pad_sequences(X_test,padding='post',maxlen=100)

# %%
X_train.shape
# Out:
# (25000, 100)

# %%
model = Sequential()
model.add(Embedding(10000,output_dim=1,input_length=100))
model.add(LSTM(32,return_sequences=False))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 100, 1)            10000
#
#  lstm_1 (LSTM)               (None, 32)                4352
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 14385 (56.19 KB)
# Trainable params: 14385 (56.19 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train,epochs=3,validation_data=(X_test,y_test),batch_size=42)
# Out:
# Epoch 1/3
# 596/596 [==============================] - 40s 64ms/step - loss: 0.4690 - accuracy: 0.7842 - val_loss: 0.4126 - val_accuracy: 0.8284
# Epoch 2/3
# 596/596 [==============================] - 11s 19ms/step - loss: 0.3073 - accuracy: 0.8727 - val_loss: 0.3460 - val_accuracy: 0.8498
# Epoch 3/3
# 596/596 [==============================] - 12s 20ms/step - loss: 0.2479 - accuracy: 0.9016 - val_loss: 0.3851 - val_accuracy: 0.8410

# %%
X_test[0].shape
# Out:
# (100,)

# %%
test_data = X_test[100][0:100].reshape(1,-1)

# %%
test_data.shape
# Out:
# (1, 100)

# %%
model.predict(test_data)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# array([[0.3443007]], dtype=float32)
